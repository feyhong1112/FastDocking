# %% [markdown]
# # 1. Install dependancies.

# %%
# !pip install pandas pandarallel tqdm
# Out:
# Requirement already satisfied: pandas in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: pandarallel in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (1.6.5)
# Requirement already satisfied: tqdm in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (4.66.4)
# Requirement already satisfied: ipynb in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (0.5.1)
# Requirement already satisfied: ipywidgets in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (7.7.2)
# Requirement already satisfied: numpy>=1.23.2 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: dill>=0.3.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from pandarallel) (0.3.8)
# Requirement already satisfied: psutil in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from pandarallel) (5.9.8)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipywidgets) (6.29.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipywidgets) (3.6.7)
# Requirement already satisfied: ipython>=4.0.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipywidgets) (8.23.0)
# Collecting jupyterlab-widgets<3,>=1.0.0 (from ipywidgets)
#   Using cached jupyterlab_widgets-1.1.8-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: comm>=0.1.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.8.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.0)
# Requirement already satisfied: packaging in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (24.0)
# Requirement already satisfied: pyzmq>=24 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.4.1)
# Requirement already satisfied: decorator in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing-extensions in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets) (4.11.0)
# Requirement already satisfied: pexpect>4.3 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets) (4.9.0)
# Requirement already satisfied: six>=1.5 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from widgetsnbextension~=3.6.0->ipywidgets) (7.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.10.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.14.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.26.0)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.1.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.3.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.3)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (7.16.3)
# Requirement already satisfied: nbformat>=5.3.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.9.2)
# Requirement already satisfied: overrides>=5.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyterlab<4.2,>=4.1.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyterlab<4.2,>=4.1.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyterlab<4.2,>=4.1.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.2.5)
# Requirement already satisfied: babel>=2.10 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.19.2)
# Requirement already satisfied: requests>=2.31 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.32.2)
# Requirement already satisfied: idna>=2.8 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: certifi in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.1.0)
# Requirement already satisfied: defusedxml in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: tinycss2 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.2.1)
# Requirement already satisfied: fastjsonschema in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.2.2)
# Requirement already satisfied: webencodings in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: fqdn in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: isoduration in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.4)
# Requirement already satisfied: uri-template in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.5)
# Requirement already satisfied: pycparser in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/lab-03/miniconda3/envs/atc_Fey/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.9.0.20240316)
# Using cached jupyterlab_widgets-1.1.8-py3-none-any.whl (237 kB)
# Installing collected packages: jupyterlab-widgets
# Successfully installed jupyterlab-widgets-1.1.8

# %%
# !jupyter labextension list
# Out:
# JupyterLab v4.2.3
# /home/lab-03/miniconda3/envs/atcgpu_Fey/share/jupyter/labextensions
#         jupyterlab_pygments v0.3.0 enabled OK (python, jupyterlab_pygments)
#         @jupyter-widgets/jupyterlab-manager v5.0.11 enabled OK (python, jupyterlab_widgets)
#         @jupyter-notebook/lab-extension v7.2.1 enabled OK

# %% [markdown]
# # 2. Import and working directory

# %%
import pandas as pd
import tqdm.notebook as tqdm
from tqdm import tqdm as tq
import glob
import pathlib
import os
import re
import numpy as np
import subprocess
tq.pandas()

from pandarallel import pandarallel

pandarallel.initialize(progress_bar=True, nb_workers=2) #6 process, each will take 8 cores, which leave me with 48 other cores (96 cores in total)
                                                        #2 process, Lab computer have 10 core
#Regex for best mode energy
regex_best_energy = re.compile(r"^1 +(-?[0-9]+\.[0-9]+) +0\.000 +0.000 +")
print("\n")
current_directory = os.getcwd()
os.chdir(current_directory)
print(current_directory)
# Out:
# INFO: Pandarallel will run on 2 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
#
#
# /home/lab-03/Desktop/GPUDock/SupperQuick_Smina (copy)

# %% [markdown]
# Go to your working directory

# %% [markdown]
# # 3. Searching for pdbqt files
#
# This will search all `pdbqt` files in `ligands` folder and put them in a pandas dataframe (used for quick parallelisation)

# %%
ligand_list = glob.glob("ligands/*.pdbqt")
df = pd.DataFrame(ligand_list, columns=["LigandFile"])
display(df)
# Out:
#             LigandFile
# 0    ligands/118.pdbqt
# 1    ligands/692.pdbqt
# 2    ligands/494.pdbqt
# 3    ligands/518.pdbqt
# 4     ligands/42.pdbqt
# ..                 ...
# 846  ligands/718.pdbqt
# 847  ligands/347.pdbqt
# 848  ligands/265.pdbqt
# 849   ligands/20.pdbqt
# 850  ligands/411.pdbqt
#
# [851 rows x 1 columns]

# %% [markdown]
# # Run processess

# %%
def run_smina(row):
    file=row.iloc[0]
    basename = pathlib.Path(file).stem
    outfolder = f"all_poses/{basename}"
    if not os.path.exists(outfolder):
        os.makedirs(outfolder)

    outputposes = f"{outfolder}/{basename}.pdbqt"
    outputlog = f"{outfolder}/{basename}.log"

    #default success = False. Only change it when it worked.
    success = False
    best_energy = np.nan
    #Check if the logfile already exist
    #if os.path.exists(outputlog):
    if False:
        with open(outputlog, "r") as log:
            stdout = log.readlines()
        success = True
    else:
        results = subprocess.run([
            "./smina.static", 
            "--config","ligand.conf",
            "--ligand", file, 
            "--out", outputposes, 
            "--log",outputlog,
            "--cpu","8", 
            "--scoring","vinardo"],
            capture_output=False)
        if results.returncode == 0:
            success = True
        if success == True:
            stdout = results.stdout.decode("utf-8").split("\n")
        

    if success == True:
        #Get the best energy
        for line in stdout:
            match = regex_best_energy.findall(line)
            if match:
                best_energy=float(match[0])
                break
            else:
                best_energy = np.nan


    return pd.Series(
            {
            "name":basename,
            "filename":file,
            "success":success,
            "BestEnergy":best_energy
            }
        )
results = df.parallel_apply(lambda x: run_smina(x), axis=1)

results.to_csv("results.csv",sep=";")
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=426), Label(value='0 / 426'))), HB…
# Process ForkPoolWorker-48:
# Process ForkPoolWorker-47:
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 55
#      44                 best_energy = np.nan
#      47     return pd.Series(
#      48             {
#      49             "name":basename,
#    (...)
#      53             }
#      54         )
# ---> 55 results = df.parallel_apply(lambda x: run_smina(x), axis=1)
#      57 results.to_csv("results.csv",sep=";")
#
# File ~/miniconda3/envs/atcgpu_Fey/lib/python3.12/site-packages/pandarallel/core.py:307, in parallelize_with_memory_file_system.<locals>.closure(data, user_defined_function, *user_defined_function_args, **user_defined_function_kwargs)
#     299 generation = count()
#     301 while any(
#     302     (
#     303         worker_status == WorkerStatus.Running
#     304         for worker_status in workers_status
#     305     )
#     306 ):
# --> 307     message: Tuple[int, WorkerStatus, Any] = master_workers_queue.get()
#     308     worker_index, worker_status, payload = message
#     309     workers_status[worker_index] = worker_status
#
# File <string>:2, in get(self, *args, **kwds)
#
# File ~/miniconda3/envs/atcgpu_Fey/lib/python3.12/multiprocessing/managers.py:821, in BaseProxy._callmethod(self, methodname, args, kwds)
#     818     conn = self._tls.connection
#     820 conn.send((self._id, methodname, args, kwds))
# --> 821 kind, result = conn.recv()
#     823 if kind == '#RETURN':
#     824     return result
#
# File ~/miniconda3/envs/atcgpu_Fey/lib/python3.12/multiprocessing/connection.py:250, in _ConnectionBase.recv(self)
#     248 self._check_closed()
#     249 self._check_readable()
# --> 250 buf = self._recv_bytes()
#     251 return _ForkingPickler.loads(buf.getbuffer())
#
# File ~/miniconda3/envs/atcgpu_Fey/lib/python3.12/multiprocessing/connection.py:430, in Connection._recv_bytes(self, maxsize)
#     429 def _recv_bytes(self, maxsize=None):
# --> 430     buf = self._recv(4)
#     431     size, = struct.unpack("!i", buf.getvalue())
#     432     if size == -1:
#
# File ~/miniconda3/envs/atcgpu_Fey/lib/python3.12/multiprocessing/connection.py:395, in Connection._recv(self, size, read)
#     393 remaining = size
#     394 while remaining > 0:
# --> 395     chunk = read(handle, remaining)
#     396     n = len(chunk)
#     397     if n == 0:
#
# KeyboardInterrupt:
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#            ^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/site-packages/pandas/core/frame.py", line 10374, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/site-packages/pandas/core/apply.py", line 916, in apply
#     return self.apply_standard()
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/site-packages/pandas/core/apply.py", line 1063, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/site-packages/pandas/core/apply.py", line 1081, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_33061/945530029.py", line 55, in <lambda>
#     results = df.parallel_apply(lambda x: run_smina(x), axis=1)
#                                           ^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#            ^^^^^^^^^^^
#   File "/tmp/ipykernel_33061/945530029.py", line 21, in run_smina
#     results = subprocess.run([
#               ^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/site-packages/pandas/core/frame.py", line 10374, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/subprocess.py", line 550, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/site-packages/pandas/core/apply.py", line 916, in apply
#     return self.apply_standard()
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/subprocess.py", line 1209, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/site-packages/pandas/core/apply.py", line 1063, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/site-packages/pandas/core/apply.py", line 1081, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/subprocess.py", line 2115, in _communicate
#     ready = selector.select(timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_33061/945530029.py", line 55, in <lambda>
#     results = df.parallel_apply(lambda x: run_smina(x), axis=1)
#                                           ^^^^^^^^^^^^
#   File "/tmp/ipykernel_33061/945530029.py", line 21, in run_smina
#     results = subprocess.run([
#               ^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/subprocess.py", line 550, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/subprocess.py", line 1209, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/subprocess.py", line 2115, in _communicate
#     ready = selector.select(timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lab-03/miniconda3/envs/atcgpu_Fey/lib/python3.12/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
results.query("BestEnergy < ")
# Out:
#     name           filename  success  BestEnergy
# 0    118  ligands/118.pdbqt     True        -6.1
# 1    494  ligands/494.pdbqt     True        -6.0
# 2    518  ligands/518.pdbqt     True        -7.4
# 3     42   ligands/42.pdbqt     True        -6.7
# 4    229  ligands/229.pdbqt     True        -5.2
# ..   ...                ...      ...         ...
# 666  576  ligands/576.pdbqt     True        -4.9
# 667  347  ligands/347.pdbqt     True        -4.6
# 668  265  ligands/265.pdbqt     True        -5.8
# 669   20   ligands/20.pdbqt     True        -6.4
# 670  411  ligands/411.pdbqt     True        -5.8
#
# [659 rows x 4 columns]

# %% [markdown]
# # Reformating the pdbqt to be "VINA LIKE" and extract the best pose

# %% [markdown]
# Vina pdbqt have a line with the result in the format `REMARK VINA X X X`.
# This code will add it by parsing the logfiles.

# %%
def reformat_and_extract_best_pose(row):
    file=row.iloc[0]
    basename = pathlib.Path(file).stem
    outfolder = f"all_poses/{basename}"
    outputposes = f"{outfolder}/{basename}.pdbqt"
    outputlog = f"{outfolder}/{basename}.log"
    regex_results = re.compile(r"^([0-9]+) +(-?[0-9]+\.[0-9]) +(-?[0-9]+\.[0-9]+) +(-?[0-9]+\.[0-9]+)")

    #default success = False. Only change it when it worked.
    success = False
    best_energy = np.nan
    #Check if the logfile already exist
    if os.path.exists(outputlog):
        with open(outputlog, "r") as log:
            stdout = log.readlines()
        success = True
        

    if success == True:
        #Get the best energy4
        scores = {}
        for line in stdout:
            match = regex_results.findall(line)
            if len(match)>0:
                model=match[0][0]
                energy=float(match[0][1])
                rmsdLB=float(match[0][2])
                rmsdUB=float(match[0][3])
                scores[model]=(energy, rmsdLB, rmsdUB)

    if success:
        newpdbqt = []
        best_model = []
        with open(outputposes,"r") as pdbqt:
            lines = pdbqt.readlines()
            model=0
            vinaLineAdded = False
            for line in lines:
                newpdbqt.append(line)
                if line.startswith("MODEL"):
                    model = line.strip().split(" ")[-1]
                    energy = float(scores[model][0])
                    rmsdLB = float(scores[model][1])
                    rmsdUB = float(scores[model][2])
                    VINALINE = f"REMARK VINA RESULT: {energy:>10.1f} {rmsdLB:>10.3f} {rmsdUB:>10.3f}\n"
                    newpdbqt.append(VINALINE)
                
                if model == "1":
                    best_model.append(line)
                    if vinaLineAdded == False:
                        best_model.append(VINALINE)
                        vinaLineAdded = True
                    

        with open(f"{outfolder}/{basename}_vinaFormat.pdbqt",'w') as vinaout:
            for line in newpdbqt:
                vinaout.write(line)

        with open(f"{outfolder}/{basename}_bestpose.pdbqt",'w') as bestout:
            for line in best_model:
                bestout.write(line)

_ = df.progress_apply(lambda x: reformat_and_extract_best_pose(x), axis=1)
# Out:
# 100%|█████████████████████████████████████| 578/578 [00:00<00:00, 118281.99it/s]
